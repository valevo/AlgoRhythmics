# %%
import guitarpro
import music21 as m21

# %%
song = guitarpro.parse('/home/arran/projects/guitarPro/Guitar Pro Tabs #1/W/White Stripes - Fell in Love With a Girl.gp3')

# %%
for track in song.tracks:
    print(track, len(track.strings), track.isPercussionTrack)
# Out:
# <guitarpro.models.Track object at 0x7f918e3f94a8> 6 False
# <guitarpro.models.Track object at 0x7f918e16f0b8> 4 False
# <guitarpro.models.Track object at 0x7f918e1aa978> 6 True

# %%
s = m21.stream.Score()

for track in song.tracks:
    print(track)
    part = m21.stream.Part()
    
    for measure in track.measures:
        m = m21.stream.Measure()
        for voice in measure.voices:
            for beat in voice.beats:
#                 print(beat.start / 960)
                for note in beat.notes:
                    print(note.realValue)
# Out:
# ...
# 54
# 47
# 54
# 47
# 54
# 47
# 54
# 47
# 54
# 47
# 54
# 47
# 52
# 45
# 52
# 45
# 52
# 45
# 52
# 45
# 52
# 45
# 52
# 45
# 57
# 50
# 57
# 50
# 57
# 50
# 57
# 50
# 57
# 50
# 57
# 50
# 47
# 40
# 47
# 40
# 47
# 40
# 47
# 40
# 47
# 40
# 47
# 40
# 54
# 47
# 54
# 47
# 54
# 47
# 54
# 47
# 54
# 47
# 54
# 47
# 52
# 45
# 52
# 45
# 52
# 45
# 52
# 45
# 52
# 45
# 52
# 45
# 57
# 50
# 57
# 50
# 57
# 50
# 57
# 50
# 57
# 50
# 57
# 50
# 47
# 40
# 47
# 40
# 47
# 40
# 47
# 40
# 47
# 40
# 47
# 40
# 49
# 42
# 49
# 42
# 49
# 42
# 49
# 42
# 49
# 42
# 49
# 42
# 52
# 45
# 52
# 45
# 52
# 45
# 52
# 45
# 52
# 45
# 52
# 45
# 57
# 50
# 57
# 50
# 57
# 50
# 57
# 50
# 57
# 50
# 57
# 50
# 47
# 40
# 47
# 40
# 47
# 40
# 47
# 40
# 47
# 40
# 47
# 40
# 49
# 42
# 54
# 47
# 54
# 47
# 54
# 47
# 54
# 47
# 54
# 47
# 54
# 47
# 52
# 45
# 52
# 45
# 52
# 45
# 52
# 45
# 52
# 45
# 52
# 45
# 57
# 50
# 57
# 50
# 57
# 50
# 57
# 50
# 57
# 50
# 57
# 50
# 47
# 40
# 47
# 40
# 47
# 40
# 47
# 40
# 47
# 40
# 47
# 40
# 49
# 42
# 49
# 42
# 49
# 42
# ...

# %%
song.key
# Out:
# <KeySignature.CMajor: (0, 0)>
